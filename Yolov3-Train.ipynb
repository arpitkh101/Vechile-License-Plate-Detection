# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/Colab Notebooks"
# Out:
# total 84
# -rw------- 1 root root 17383 Feb  5 12:11 'Copy of BasicsPytorch.ipynb'
# -rw------- 1 root root 25667 Mar 18 09:13 'Copy of Tutorial DarknetToColab.ipynb'
# -rw------- 1 root root   317 Mar 18 04:41  Untitled
# -rw------- 1 root root  1146 Mar 15 13:21  Untitled0.ipynb
# -rw------- 1 root root  3591 Apr  8 17:42  Untitled1.ipynb
# -rw------- 1 root root   345 Mar 20 17:08  Untitled2.ipynb
# -rw------- 1 root root 34646 Mar 20 17:04  Untitled.ipynb
# -rw------- 1 root root   347 Apr  8 13:58  Yolo-custom.ipynb

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !tar -xzvf gdrive/My\ Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.solitairetheme8 -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make

#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 9.94 MiB | 11.00 MiB/s, done.
# Resolving deltas: 100% (6758/6758), done.
# /content/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# ...

# %%
cd /content/gdrive/My Drive/darknet/bin/darknet
# Out:
# /content/gdrive/My Drive/darknet/bin/darknet

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-custom.cfg" "/content/gdrive/My Drive/darknet/weights/darknet53.conv.74" -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  207: 3.108659, 4.545313 avg loss, 0.000002 rate, 3.323419 seconds, 13248 images
# Loaded: 0.000059 seconds
#
#  208: 3.052968, 4.396079 avg loss, 0.000002 rate, 3.319890 seconds, 13312 images
# Loaded: 0.000039 seconds
#
#  209: 2.980809, 4.254551 avg loss, 0.000002 rate, 3.329210 seconds, 13376 images
# Loaded: 0.000032 seconds
#
#  210: 3.035768, 4.132673 avg loss, 0.000002 rate, 3.316270 seconds, 13440 images
# Loaded: 0.000046 seconds
#  Very small path to the image:
#  Very small path to the image:
#
#  211: 3.114430, 4.030849 avg loss, 0.000002 rate, 3.330863 seconds, 13504 images
# Loaded: 0.000039 seconds
#
#  212: 2.973058, 3.925070 avg loss, 0.000002 rate, 3.329371 seconds, 13568 images
# Loaded: 0.000043 seconds
#
#  213: 3.024634, 3.835026 avg loss, 0.000002 rate, 3.328113 seconds, 13632 images
# Loaded: 0.000032 seconds
#  Very small path to the image:
#
# ...

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-custom.cfg" "/content/gdrive/My Drive/darknet/backup/yolov3-custom_last.weights" -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  2490: 0.074149, 0.083079 avg loss, 0.001000 rate, 3.353746 seconds, 159360 images
# Loaded: 0.000042 seconds
#
#  2491: 0.071406, 0.081912 avg loss, 0.001000 rate, 3.335519 seconds, 159424 images
# Loaded: 0.000067 seconds
#
#  2492: 0.057777, 0.079498 avg loss, 0.001000 rate, 3.349918 seconds, 159488 images
# Loaded: 0.000058 seconds
#  Very small path to the image:
#
#  2493: 0.082014, 0.079750 avg loss, 0.001000 rate, 3.323875 seconds, 159552 images
# Loaded: 0.000039 seconds
#
#  2494: 0.071176, 0.078892 avg loss, 0.001000 rate, 3.328387 seconds, 159616 images
# Loaded: 0.000056 seconds
#
#  2495: 0.071093, 0.078112 avg loss, 0.001000 rate, 3.316388 seconds, 159680 images
# Loaded: 0.000047 seconds
#  Very small path to the image:
#
#  2496: 0.056166, 0.075918 avg loss, 0.001000 rate, 3.323410 seconds, 159744 images
# Loaded: 0.000060 seconds
#
# ...

# %%
# !./darknet detector map "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-custom.cfg" "/content/gdrive/My Drive/darknet/backup/yolov3-custom_final.weights" -dont_show
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detector map "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3-custom.cfg" "/content/gdrive/My Drive/darknet/backup/yolov3-custom_final.weights" -dont_show
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...
